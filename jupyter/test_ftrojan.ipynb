# %%
import torch
import PIL
import PIL.Image
import numpy as np
import matplotlib.pylab as plt

# %%
img = PIL.Image.open('/home/chengyiqiu/code/INBA/resource/example/cifar10_benign.png')
img = img.resize((32 ,32))
x_0 = np.array(img)
# Out:
# (32, 32, 3)
